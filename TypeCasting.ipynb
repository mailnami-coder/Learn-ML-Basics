# %% [markdown]
# <a href="https://colab.research.google.com/github/mailnami-coder/Learn-ML-Basics/blob/main/TypeCasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Typecasting
# It the process of converting one data type to another datatype
#
# Syntax:
# datatype(var/value)

# %%
#Int Typecasting - It is the process of converting int data type into other data type.
#Int can be convertible into all SVDT data types
#When we try to convert into collection DT the conversion is possible only for string DT
#It is not possible for other collection data type

a=10
print(type(a))
print(type(float(a)))
print(type(str(a)))
print(type(complex(a)))
print(type(bool(a)))
print(type(str(a)))
#Below is not possible. Uncomment and run to see the error.
#print(type(list(a)))
#print(type(tuple(a)))
#print(type(set(a)))
#print(type(dict(a)))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'complex'>
# <class 'bool'>
# <class 'str'>

# %%
#Float type Casting - Process of converting float DT to other DT's
#Float can be converted to any SVDT
#In Collection DT float can converted only to string DT and other MVDT is not possible.

a=10.5
print(type(a),a)
print(type(int(a)),int(a))
print(type(str(a)),str(a))
print(type(complex(a)),complex(a))
print(type(bool(a)),bool(a))
print(type(str(a)),str(a))

#Below is not possible. Uncomment and run to see the error.
#print(type(list(a)))
#print(type(tuple(a)))
#print(type(set(a)))
#print(type(dict(a)))
# Out:
# <class 'float'> 10.5
# <class 'int'> 10
# <class 'str'> 10.5
# <class 'complex'> (10.5+0j)
# <class 'bool'> True
# <class 'str'> 10.5

# %%
#Complex DT casting
#Complex DT is convertible only to the bool and string DT, rest of the DT is not possible.

a=10+4j
print(bool(a),type(bool(a)))
print(str(a),type(str(a)))

#All below statements will cause error
#print(int(a),type(int(a)))
#print(float(a),type(float(a)))
#print(list(a),type(list(a)))
# Out:
# True <class 'bool'>
# (10+4j) <class 'str'>

# %%
#Boolean Typecasting - It can be convertible into all the SVDT
#Incase of MVDT only string is possible, other MVDT is not possible.

# %%
a=True
print(type(a))
print(type(str(a)),str(a))
b=str(a)
print(type(b))
if b=="True":
    print("True")
else:
    print("False")
#
# Out:
# <class 'bool'>
# <class 'str'> True
# <class 'str'>
# True

# %% [markdown]
# # String Typecasting
#
# String can be converted into all the SVDT, but it should only have base of 10 values
#
# String can be converted to all the collection datatype except Dictionary DT

# %%
a='gowri'
b='9'
print(list(a),type(a))
print(tuple(a),type(a))
print(set(a),type(a))
print(int(b),type(int(b)))
print(float(b),type(float(b)))
print(complex(b),type(complex(b)))
print(bool(a),type(bool(a)))
#print(dict(a),type(a))
# Out:
# ['g', 'o', 'w', 'r', 'i'] <class 'str'>
# ('g', 'o', 'w', 'r', 'i') <class 'str'>
# {'w', 'o', 'i', 'r', 'g'} <class 'str'>
# 9 <class 'int'>
# 9.0 <class 'float'>
# (9+0j) <class 'complex'>
# True <class 'bool'>

# %% [markdown]
# # List TypeCasting
# List is convertible only to bool DT,other SVDT is not possible
#
# List can be converted to all MVDT but for Dictionary data type it should have nested collection with two values.

# %%
a=[1,2,3,4]
print(bool(a),type(bool(a)))
print(tuple(a),type(tuple(a)))
print(set(a),type(set(a)))
print(str(a),type(str(a)))
b=[[1,11],[2,22],[3,33]]
print(dict(b),type(dict(b)))
# Out:
# True <class 'bool'>
# (1, 2, 3, 4) <class 'tuple'>
# {1, 2, 3, 4} <class 'set'>
# [1, 2, 3, 4] <class 'str'>
# {1: 11, 2: 22, 3: 33} <class 'dict'>

# %% [markdown]
# ##Tuple Typecasting
# Tuple can be converted only to bool DT, other SVDT is not possible
#
# Tuple can be converted to all MVDT, incase of DICT it should be nested collection with two values.

# %%
a=(1,2,4,56,6)
print(bool(a),type(bool(a)))
print(str(a),type(str(a)))
print(list(a),type(list(a)))
print(set(a),type(set(a)))
b=((1,10),(2,20),(3,30))
print(dict(b),type(dict(b)))
b=((4,40),(5,50))
print(dict(b),type(dict(b)))
# Out:
# True <class 'bool'>
# (1, 2, 4, 56, 6) <class 'str'>
# [1, 2, 4, 56, 6] <class 'list'>
# {1, 2, 4, 6, 56} <class 'set'>
# {1: 10, 2: 20, 3: 30} <class 'dict'>
# {4: 40, 5: 50} <class 'dict'>

# %% [markdown]
# ##Set TypeCasting
# Set can be converted only to bool DT, other SVDT is not possible
#
# Set can be converted to all MVDT, incase of DICT it should be nested collection with two values.

# %%
a={1,4,7,9}
print(type(a))
print(bool(a),type(bool(a)))
print(list(a),type(list(a)))
print(tuple(a),type(tuple(a)))
print(str(a),type(str(a)))
b=({1,10},{2,20},{3,30})
print(dict(b),type(dict(b)))
b=({4,40},{5,50})
print(dict(b),type(dict(b)))
# Out:
# <class 'set'>
# True <class 'bool'>
# [1, 4, 9, 7] <class 'list'>
# (1, 4, 9, 7) <class 'tuple'>
# {1, 4, 9, 7} <class 'str'>
# {1: 10, 2: 20, 3: 30} <class 'dict'>
# {40: 4, 50: 5} <class 'dict'>

# %% [markdown]
# ##Dictionary Typecasting
# It can be convertible into bool and String DT,other SVDT is not possible.
#
# Dictionary DT can be converted into all MVDT DT, but when we try to convert
# dictionary into other MVDT only keys will be present because that is the only
# visible layer of a dictionary

# %%
a={1:'a',2:'b',3:'c'}
print(type(a))
print(bool(a),type(bool(a)))
print(list(a),type(list(a)))
print(tuple(a),type(tuple(a)))
print(str(a),type(str(a)))
print(set(a),type(set(a)))
# Out:
# <class 'dict'>
# True <class 'bool'>
# [1, 2, 3] <class 'list'>
# (1, 2, 3) <class 'tuple'>
# {1: 'a', 2: 'b', 3: 'c'} <class 'str'>
# {1, 2, 3} <class 'set'>
